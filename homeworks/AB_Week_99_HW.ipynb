# %% [markdown]
# ## ❌ DO NOT EDIT — MAKE A COPY
# # Test Week 99 Homework (fixture, not real coursework)
# Used to sanity-check the auto-review workflow. Not a real assignment.

# %% [markdown]
# **Q1.** Write a function `double(n)` that returns `n * 2`.

# %%
def double(n):
    return n * 2

# %% [markdown]
# **Q2.** Set the variable `favorite_number` to any integer.

# %%
favorite_number = 7
